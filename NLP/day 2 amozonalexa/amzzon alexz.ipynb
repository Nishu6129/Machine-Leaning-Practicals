# %%
import pandas

# %%
dataset=pandas.read_csv("amazon_alexa.tsv",delimiter="\t")

# %%
dataset["variation"].value_counts()
# Out:
# variation
# Black  Dot                      516
# Charcoal Fabric                 430
# Configuration: Fire TV Stick    350
# Black  Plus                     270
# Black  Show                     265
# Black                           261
# Black  Spot                     241
# White  Dot                      184
# Heather Gray Fabric             157
# White  Spot                     109
# White                            91
# Sandstone Fabric                 90
# White  Show                      85
# White  Plus                      78
# Oak Finish                       14
# Walnut Finish                     9
# Name: count, dtype: int64

# %%
dataset
# Out:
#       rating       date         variation  \
# 0          5  31-Jul-18  Charcoal Fabric
# 1          5  31-Jul-18  Charcoal Fabric
# 2          4  31-Jul-18    Walnut Finish
# 3          5  31-Jul-18  Charcoal Fabric
# 4          5  31-Jul-18  Charcoal Fabric
# ...      ...        ...               ...
# 3145       5  30-Jul-18        Black  Dot
# 3146       5  30-Jul-18        Black  Dot
# 3147       5  30-Jul-18        Black  Dot
# 3148       5  30-Jul-18        White  Dot
# 3149       4  29-Jul-18        Black  Dot
#
#                                        verified_reviews  feedback
# 0                                         Love my Echo!         1
# 1                                             Loved it!         1
# 2     Sometimes while playing a game, you can answer...         1
# 3     I have had a lot of fun with this thing. My 4 ...         1
# 4                                                 Music         1
# ...

# %%
dataset["verified_reviews"]
# Out:
# 0                                           Love my Echo!
# 1                                               Loved it!
# 2       Sometimes while playing a game, you can answer...
# 3       I have had a lot of fun with this thing. My 4 ...
# 4                                                   Music
#                               ...
# 3145    Perfect for kids, adults and everyone in betwe...
# 3146    Listening to music, searching locations, check...
# 3147    I do love these things, i have them running my...
# 3148    Only complaint I have is that the sound qualit...
# 3149                                                 Good
# Name: verified_reviews, Length: 3150, dtype: object

# %%
dataset['Length']=dataset["verified_reviews"].apply(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dataset['Length']=dataset["verified_reviews"].apply(len)
#
# File D:\Anaconda\Lib\site-packages\pandas\core\series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# File D:\Anaconda\Lib\site-packages\pandas\core\apply.py:1209, in SeriesApply.apply(self)
# ...

# %%
dataset.describe(include="object")
# Out:
#              date   variation verified_reviews
# count        3150        3150             3149
# unique         77          16             2300
# top     30-Jul-18  Black  Dot
# freq         1603         516               79

# %%
from textblob import TextBlob

# %%
mysen=TextBlob("Love my echo!")

# %%
mysen.sentiment
# Out:
# Sentiment(polarity=0.625, subjectivity=0.6)

# %%
def get_sent(text):
    if isinstance(text, str):
        mytext=TextBlob(text)
        mysent=mytext.sentiment
        return mysent.polarity
    else:
        print(text)
        text=str(text)
        mytext=TextBlob(text)
        mysent=mytext.sentiment
        return mysent.polarity

# %%
get_sent("Configuration: Fire TV Stick")
# Out:
# 0.0

# %%
dataset["polarity"]=dataset["verified_reviews"].apply(get_sent)
# Out:
# nan

# %%
dataset
# Out:
#       rating       date         variation  \
# 0          5  31-Jul-18  Charcoal Fabric
# 1          5  31-Jul-18  Charcoal Fabric
# 2          4  31-Jul-18    Walnut Finish
# 3          5  31-Jul-18  Charcoal Fabric
# 4          5  31-Jul-18  Charcoal Fabric
# ...      ...        ...               ...
# 3145       5  30-Jul-18        Black  Dot
# 3146       5  30-Jul-18        Black  Dot
# 3147       5  30-Jul-18        Black  Dot
# 3148       5  30-Jul-18        White  Dot
# 3149       4  29-Jul-18        Black  Dot
#
#                                        verified_reviews  feedback  polarity
# 0                                         Love my Echo!         1  0.625000
# 1                                             Loved it!         1  0.875000
# 2     Sometimes while playing a game, you can answer...         1 -0.100000
# 3     I have had a lot of fun with this thing. My 4 ...         1  0.350000
# 4                                                 Music         1  0.000000
# ...

# %%
def get_sent_sub(text):
    if isinstance(text, str):
        mytext=TextBlob(text)
        mysent=mytext.sentiment
        return mysent.subjectivity
    else:
        print(text)
        text=str(text)
        mytext=TextBlob(text)
        mysent=mytext.sentiment
        return mysent.subjectivity

# %%
dataset["subjectivity"]=dataset["verified_reviews"].apply(get_sent_sub)
# Out:
# nan

# %%
dataset
# Out:
#       rating       date         variation  \
# 0          5  31-Jul-18  Charcoal Fabric
# 1          5  31-Jul-18  Charcoal Fabric
# 2          4  31-Jul-18    Walnut Finish
# 3          5  31-Jul-18  Charcoal Fabric
# 4          5  31-Jul-18  Charcoal Fabric
# ...      ...        ...               ...
# 3145       5  30-Jul-18        Black  Dot
# 3146       5  30-Jul-18        Black  Dot
# 3147       5  30-Jul-18        Black  Dot
# 3148       5  30-Jul-18        White  Dot
# 3149       4  29-Jul-18        Black  Dot
#
#                                        verified_reviews  feedback  polarity  \
# 0                                         Love my Echo!         1  0.625000
# 1                                             Loved it!         1  0.875000
# 2     Sometimes while playing a game, you can answer...         1 -0.100000
# 3     I have had a lot of fun with this thing. My 4 ...         1  0.350000
# 4                                                 Music         1  0.000000
# ...

# %%
dataset[["polarity",'subjectivity']]
# Out:
#       polarity  subjectivity
# 0     0.625000      0.600000
# 1     0.875000      0.800000
# 2    -0.100000      0.512500
# 3     0.350000      0.450000
# 4     0.000000      0.000000
# ...        ...           ...
# 3145  1.000000      1.000000
# 3146  0.333333      0.452381
# 3147  0.237662      0.533766
# 3148  0.316667      0.632099
# 3149  0.700000      0.600000
#
# [3150 rows x 2 columns]

# %%
dataset[["polarity",'subjectivity']].describe()
# Out:
#           polarity  subjectivity
# count  3150.000000   3150.000000
# mean      0.349786      0.528988
# std       0.303308      0.256261
# min      -1.000000      0.000000
# 25%       0.123852      0.419196
# 50%       0.350000      0.584848
# 75%       0.533333      0.694444
# max       1.000000      1.000000
